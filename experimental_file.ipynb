# %%
def run_experiment(top_selected_number,feature_names_list, X, y, models):
    print(f"The number of features used are {top_selected_number} and the contain {feature_names_list}.")
    print("-"*50)
    current_df = X[feature_names_list]
    current_df.head(3)
    #sampling the data.
    current_df  = current_df.sample(frac = 1, random_state= 42).reset_index(drop = True)
    #splitting the data
    X_train, X_test, y_train, y_test = train_test_split(current_df,y,test_size = 0.25, random_state = 42)
    #Model_training.
    result = []
    for model_name,model  in models.items():
        print(f"Using the {model_name}")
        model.train(X_train,y_train)
        y_pred = model.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        results.append({
            'Model': name,
            'R2_Score': r2,
            'RMSE': rmse,
            'Train_Time_sec': train_time
        })
        results_df = pd.DataFrame(results).sort_values('R2_Score', ascending=False)
        return results_df
